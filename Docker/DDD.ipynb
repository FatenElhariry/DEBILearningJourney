# %% [markdown]
# ![image.png](attachment:7c8aa4d3-9dd9-4a63-90e8-071691b3b749.png)

# %% [markdown]
# # DDD
#  > the word **Domain driven** refer to the business and the operation and the word **design** refer to the software implementation
# ## Stratgic part
#    ### define Domine
#    - Core domain
#    - SubDomains
#    - Support Domain
#    ### Dounded Context
#        > define the main related parts and the relation between each part and the other domains in the solution
#    ### Ubiquitous Languages
#
#    ### Problem Space Vs Solution Space
#    > **Problem Space** : is the relate to the client defined tasks
#       **Solution Space** : it is relate to the development operation
#
# ## tactical part
# > to define the behvior of your system you need to focus on the event => help us to understand the beheviour of the domain
# - if you book an apointment you need to
#    - reserve the room
#    - deducate the doctor based on the schedule
#    - send confrimation email to the client
#    - calculate bill and add it on the cutstomer account
# - you can use event modeling to discuss it or through meetings with appropriate number of domain expert
# **_After undarstanding the needs of the behviour of the system_**
# ### Domain model Types
#   #### Anemic Model
#   > focus on the state of each object
#   #### Rich Model
